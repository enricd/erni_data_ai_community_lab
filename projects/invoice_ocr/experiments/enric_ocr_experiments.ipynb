# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
from PIL import Image
import numpy as np
import urllib.request
import pytesseract

# %%
# Read the image from the URL and convert it to OpenCV format
def read_image_from_url(url):
    with urllib.request.urlopen(url) as url_response:
        image_array = np.asarray(bytearray(url.read()), dtype=np.uint8)
        image = cv2.imdecode(image_array, cv2.IMREAD_COLOR)
    return image

def read_image_from_file(file):
    image = cv2.imread(file)
    return image

# Load the image and preprocess it
def preprocess_image(image):
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, threshold_image = cv2.threshold(gray_image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    return threshold_image

# Extract text from the image
def extract_text(image):
    processed_image = preprocess_image(image)
    text = pytesseract.image_to_string(processed_image)
    return text

# %%
image = read_image_from_file("../data/invoice_examples/ticket1.jpg")

plt.imshow(image)

# %%
processed_image = preprocess_image(image)

plt.imshow(processed_image)

# %%
# Main function

image = np.array
extracted_text = extract_text(image)
print("Extracted Text:")
print(extracted_text)
# Out:
# Extracted Text:
# RRA AEE ER EE EEE ER EEE
#
# RECEIPT
#
# HHA LEE RAEN EAE EERE IA
# Terminal#2 09-10-2018 10:49AM.
#
# 1x TShirt
# 1x T-Shirt
# 1x Pants
#
# 1x Socks
#
# CHANGE
#
# Bank Card HREK EERE EERE 6809
#
# HHHHREEEEXTHANK YOUR EERE REERS
